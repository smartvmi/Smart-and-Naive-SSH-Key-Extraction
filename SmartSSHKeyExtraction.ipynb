# %%
import os
import time
import numpy as np
from utils import print_, init, close, get_dataset_file_paths, load_models, read_key_files
from timeit import default_timer as timer
init() # Initialize the logging files

# %%
def generate_rle_representation(data):
    reshaped = np.reshape(data, newshape=(int(len(data) / 8), 8))

    # Here we take reshaped array and compute the numerical row and column wise gradient and count the number
    # of zeroes in each row. If there are more than 4 zeros which means there is a pattern repeating and
    # is not a key. This is a very conservative estimate for better recall
    num_row = int(len(data) / 8)

    # x_grad = np.abs(np.diff(reshaped.astype(int), axis=1, append=np.zeros((num_row, 1)))).astype(bool)
    # y_grad = np.abs(np.diff(reshaped.astype(int), axis=0, append=np.zeros((1, 8)))).astype(bool)
    # The above numerical gradient computation is transformed into a single step below

    poss_key_locs = (np.count_nonzero(np.abs(np.diff(reshaped.astype(int), axis=1,
                                                     append=np.zeros((num_row, 1)))).astype(bool) &
                                      np.abs(np.diff(reshaped.astype(int), axis=0,
                                                     append=np.zeros((1, 8)))).astype(bool),
                                      axis=1) >= 4).astype(int)  # Changed from 4 to 3 to accommodate for 12 byte keys

    # This part addresses the issue of 12 byte keys. There could be two identical characters next to each other in the
    # last 4 bytes which would make it impossible for a key loc. We modify that if there is a possibility for a key
    idx = 1
    while idx < len(poss_key_locs):
        # Last 4 characters must be zeros and first four should have at least 3 unique characters
        if poss_key_locs[idx] == 0 and poss_key_locs[idx-1] == 1 and \
                all(reshaped[idx][4:]) == 0 and len(set(reshaped[idx][:4])) > 2:
            poss_key_locs[idx] = 1
        idx += 1

    # Roll the data to the left
    rolled = np.roll(poss_key_locs, -1)
    # The key cannot start at the last byte and then the block contain the whole key.
    # So the last value is set to False
    rolled[-1] = False
    poss_key_locs = (poss_key_locs & rolled).astype(int)

    # Roll right and OR it. The whole operation is similar to the opening morphological operation
    rolled = np.roll(poss_key_locs, 1)
    rolled[0] = False

    poss_key_locs = poss_key_locs | rolled

    characters, counts = get_run_length_encoded(poss_key_locs)

    cum_sum = [0]

    for idx in range(len(counts)):
        cum_sum.append(cum_sum[idx] + counts[idx])

    cum_sum = [x * 8 for x in cum_sum]

    # The last offset is not required for the cumulative sum
    return characters, counts, cum_sum[:-1]

# %%
def get_slices(data, offsets, keys, max_key_size=128):
    data_blocks = []
    labels = []
    last_frame_added = False
    key_count = [0] * len(keys)
    for offset in offsets:
        if offset + max_key_size > len(data):
            curr_data = data[-max_key_size:]
            last_frame_added = True
        else:
            curr_data = data[offset:offset+max_key_size]
        data_blocks.append(curr_data)

        found = [l_idx for l_idx in range(len(keys)) if keys[l_idx] in curr_data]

        if len(found) > 0:
            labels.append(1)
            for key_idx in set(found):
                key_count[key_idx] += 1

        else:
            labels.append(0)

        if last_frame_added is True:
            break

    assert len(data_blocks) == len(labels)
    assert sum(labels) > 0 and sum(labels) >= len(keys)
    assert min(key_count) != 0
    return data_blocks, labels

# %%
def build_encoded_dataset(heap_paths, key_paths, max_key_size=128, deploy=False):

    dataset = []
    labels = []

    for heap_path, key_path in zip(heap_paths, key_paths):

        # Check if the key path corresponds to the heap path, then read the required data
        if deploy is False:
            assert (key_path[:-5] in heap_path)
            curr_keys = read_key_files(key_path)
            # Remove repeated keys. This is an issue for some older versions of OpenSSH
            curr_keys = list(map(bytearray, set(tuple(x) for x in curr_keys)))

        with open(heap_path, "rb") as fp:
            data = bytearray(fp.read())

        characters, counts, cum_sum = generate_rle_representation(data)

        viable_offsets = [cum_sum[idx] for idx in range(len(cum_sum)) if characters[idx] == 1]
        slices, curr_labels = get_slices(data=data, offsets=viable_offsets, max_key_size=max_key_size, keys=curr_keys)
        dataset = dataset + slices
        labels = labels + curr_labels

    assert len(labels) == len(dataset)
    return dataset, labels

# %%
def generate_probable_slices(clf, heap_paths, key_paths, root_dir):
    # Sort the heap paths and key paths, so it easier to group them by version and key length
    heap_paths.sort()
    key_paths.sort()
    
    # For each of the keys
    for idx in range(len(key_paths)):
        start = time.time()
        dataset, curr_labels = build_encoded_dataset(heap_paths=[heap_paths[idx]],
                                                     key_paths=[key_paths[idx]])

        x_test = np.array(dataset).astype(int)
        curr_pred = clf.predict(x_test)

        path_idx = key_paths[idx].rfind("/")
        file_name = key_paths[idx][path_idx+1:-4] + "txt"
        sub_dir = key_paths[idx][len(root_dir)+1:path_idx]
        dir_path = os.path.join(WRITE_PATH, sub_dir)
        path = os.path.join(dir_path, file_name)
        if os.path.exists(dir_path) is False:
            os.makedirs(dir_path)

        with open(path, 'w') as fp:
            for inner_idx, pred in enumerate(curr_pred):
                if pred == 0:
                    continue

                temp = ''.join(format(x, '02x') for x in dataset[inner_idx])
                fp.write(temp + "\n")

        end = time.time()
        print_('Total time taken for file %s: %f' % (heap_paths[idx], (end - start)))

# %%
def get_run_length_encoded(data_block):

    idx = 1
    characters = []
    counts = []
    count = 1
    curr_char = data_block[0]
    while idx < len(data_block):
        if data_block[idx] == curr_char:
            idx += 1
            count += 1
            continue

        else:
            characters.append(curr_char)
            counts.append(count)

            count = 1
            curr_char = data_block[idx]

        idx += 1

    # Append the last character and count
    characters.append(curr_char)
    counts.append(count)

    return bytearray(characters), counts

# %%
TEST = '/Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr'  # Path to the dataset
WRITE_PATH = '/tmp/output/' # Output file path

# Load the models
clf = load_models(load_high_recall_only=True)
# Out:
# 2022-04-26 16:52:40.358479:	Time taken for loading high recall classifier: 0.954829

# %%
# Search for all the files with in the test directory
# start = time.time()
start = timer()
heap_paths, key_paths = get_dataset_file_paths(TEST)
end = timer()
# end = time.time()
print_('Time taken for finding all files: %f' % (end - start))
# Out:
# 2022-04-26 16:52:40.364332:	Time taken for finding all files: 0.003033

# %%
generate_probable_slices(clf=clf, heap_paths=heap_paths, key_paths=key_paths, root_dir=TEST)
# Out:
# 2022-04-26 16:52:40.380383:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10237-1650982250-heap.raw: 0.013537
# 2022-04-26 16:52:40.393101:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10240-1650982250-heap.raw: 0.012651
# 2022-04-26 16:52:40.406133:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10243-1650982250-heap.raw: 0.013007
# 2022-04-26 16:52:40.418621:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10246-1650982250-heap.raw: 0.012471
# 2022-04-26 16:52:40.430694:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10249-1650982250-heap.raw: 0.012057
# 2022-04-26 16:52:40.442727:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10252-1650982250-heap.raw: 0.012015
# 2022-04-26 16:52:40.454687:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10255-1650982250-heap.raw: 0.011947
# 2022-04-26 16:52:40.466183:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10258-1650982250-heap.raw: 0.011483
# 2022-04-26 16:52:40.477829:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10261-1650982250-heap.raw: 0.011635
# 2022-04-26 16:52:40.489252:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10264-1650982250-heap.raw: 0.011411
# 2022-04-26 16:52:40.500730:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10267-1650982250-heap.raw: 0.011457
# 2022-04-26 16:52:40.512329:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10270-1650982250-heap.raw: 0.011582
# 2022-04-26 16:52:40.524290:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10273-1650982250-heap.raw: 0.011950
# 2022-04-26 16:52:40.535658:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10276-1650982250-heap.raw: 0.011357
# 2022-04-26 16:52:40.547075:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10279-1650982250-heap.raw: 0.011405
# 2022-04-26 16:52:40.558282:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10282-1650982250-heap.raw: 0.011189
# 2022-04-26 16:52:40.570307:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10285-1650982250-heap.raw: 0.012011
# 2022-04-26 16:52:40.582712:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10288-1650982250-heap.raw: 0.012350
# 2022-04-26 16:52:40.595120:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10291-1650982250-heap.raw: 0.012353
# 2022-04-26 16:52:40.606735:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10294-1650982250-heap.raw: 0.011601
# 2022-04-26 16:52:40.618649:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10297-1650982250-heap.raw: 0.011895
# 2022-04-26 16:52:40.630062:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10300-1650982250-heap.raw: 0.011398
# 2022-04-26 16:52:40.641801:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10303-1650982250-heap.raw: 0.011724
# 2022-04-26 16:52:40.653424:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10306-1650982250-heap.raw: 0.011606
# 2022-04-26 16:52:40.665039:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10309-1650982250-heap.raw: 0.011601
# 2022-04-26 16:52:40.676748:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10312-1650982250-heap.raw: 0.011697
# 2022-04-26 16:52:40.688545:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10315-1650982250-heap.raw: 0.011784
# 2022-04-26 16:52:40.700085:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10318-1650982250-heap.raw: 0.011528
# 2022-04-26 16:52:40.711569:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10321-1650982250-heap.raw: 0.011469
# 2022-04-26 16:52:40.722827:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10324-1650982250-heap.raw: 0.011242
# 2022-04-26 16:52:40.734090:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10327-1650982250-heap.raw: 0.011252
# 2022-04-26 16:52:40.745413:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10330-1650982250-heap.raw: 0.011312
# 2022-04-26 16:52:40.756787:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10333-1650982250-heap.raw: 0.011364
# 2022-04-26 16:52:40.768079:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10336-1650982250-heap.raw: 0.011276
# 2022-04-26 16:52:40.780180:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10339-1650982250-heap.raw: 0.012090
# 2022-04-26 16:52:40.792260:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10342-1650982250-heap.raw: 0.012033
# 2022-04-26 16:52:40.805093:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10345-1650982250-heap.raw: 0.012782
# 2022-04-26 16:52:40.817483:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10348-1650982250-heap.raw: 0.012368
# 2022-04-26 16:52:40.829690:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10351-1650982250-heap.raw: 0.012188
# 2022-04-26 16:52:40.842027:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10354-1650982250-heap.raw: 0.012292
# 2022-04-26 16:52:40.872158:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10357-1650982250-heap.raw: 0.030111
# 2022-04-26 16:52:40.884219:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10360-1650982250-heap.raw: 0.012038
# 2022-04-26 16:52:40.896047:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10363-1650982250-heap.raw: 0.011815
# 2022-04-26 16:52:40.907806:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10366-1650982250-heap.raw: 0.011741
# 2022-04-26 16:52:40.919427:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10370-1650982250-heap.raw: 0.011605
# 2022-04-26 16:52:40.930998:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10373-1650982250-heap.raw: 0.011557
# 2022-04-26 16:52:40.942474:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10376-1650982250-heap.raw: 0.011465
# 2022-04-26 16:52:40.954236:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10379-1650982250-heap.raw: 0.011744
# 2022-04-26 16:52:40.965683:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10382-1650982250-heap.raw: 0.011434
# 2022-04-26 16:52:40.977002:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10385-1650982250-heap.raw: 0.011308
# 2022-04-26 16:52:40.988907:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10388-1650982250-heap.raw: 0.011895
# 2022-04-26 16:52:41.001312:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10391-1650982250-heap.raw: 0.012350
# 2022-04-26 16:52:41.013785:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10394-1650982250-heap.raw: 0.012427
# 2022-04-26 16:52:41.025866:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10397-1650982250-heap.raw: 0.012063
# 2022-04-26 16:52:41.037978:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10400-1650982250-heap.raw: 0.012091
# 2022-04-26 16:52:41.049588:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10403-1650982250-heap.raw: 0.011595
# 2022-04-26 16:52:41.061155:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10406-1650982250-heap.raw: 0.011549
# 2022-04-26 16:52:41.072625:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10409-1650982250-heap.raw: 0.011458
# 2022-04-26 16:52:41.084317:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10412-1650982250-heap.raw: 0.011680
# 2022-04-26 16:52:41.096363:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10415-1650982250-heap.raw: 0.012027
# 2022-04-26 16:52:41.108608:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10418-1650982250-heap.raw: 0.012228
# 2022-04-26 16:52:41.120748:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10421-1650982250-heap.raw: 0.012120
# 2022-04-26 16:52:41.132537:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10424-1650982250-heap.raw: 0.011772
# 2022-04-26 16:52:41.145061:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10427-1650982250-heap.raw: 0.012504
# 2022-04-26 16:52:41.156559:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10430-1650982250-heap.raw: 0.011482
# 2022-04-26 16:52:41.168476:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10433-1650982250-heap.raw: 0.011902
# 2022-04-26 16:52:41.180253:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10436-1650982250-heap.raw: 0.011761
# 2022-04-26 16:52:41.192375:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10439-1650982250-heap.raw: 0.012108
# 2022-04-26 16:52:41.205229:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10442-1650982250-heap.raw: 0.012806
# 2022-04-26 16:52:41.220738:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10445-1650982250-heap.raw: 0.015443
# 2022-04-26 16:52:41.233437:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10448-1650982250-heap.raw: 0.012679
# 2022-04-26 16:52:41.245404:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10451-1650982250-heap.raw: 0.011947
# 2022-04-26 16:52:41.257658:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10454-1650982250-heap.raw: 0.012230
# 2022-04-26 16:52:41.269492:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10457-1650982250-heap.raw: 0.011814
# 2022-04-26 16:52:41.281160:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10460-1650982250-heap.raw: 0.011652
# 2022-04-26 16:52:41.293417:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10463-1650982250-heap.raw: 0.012234
# 2022-04-26 16:52:41.306122:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10466-1650982250-heap.raw: 0.012683
# 2022-04-26 16:52:41.317812:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10469-1650982250-heap.raw: 0.011670
# 2022-04-26 16:52:41.329594:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10472-1650982250-heap.raw: 0.011747
# 2022-04-26 16:52:41.341674:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10475-1650982250-heap.raw: 0.012065
# 2022-04-26 16:52:41.353256:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10478-1650982250-heap.raw: 0.011568
# 2022-04-26 16:52:41.364760:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10481-1650982250-heap.raw: 0.011491
# 2022-04-26 16:52:41.376034:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10484-1650982250-heap.raw: 0.011263
# 2022-04-26 16:52:41.387276:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10487-1650982250-heap.raw: 0.011231
# 2022-04-26 16:52:41.399090:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10490-1650982250-heap.raw: 0.011803
# 2022-04-26 16:52:41.411149:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10493-1650982250-heap.raw: 0.012021
# 2022-04-26 16:52:41.423389:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10496-1650982250-heap.raw: 0.012196
# 2022-04-26 16:52:41.434921:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10499-1650982250-heap.raw: 0.011517
# 2022-04-26 16:52:41.446667:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10502-1650982250-heap.raw: 0.011731
# 2022-04-26 16:52:41.458310:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10505-1650982250-heap.raw: 0.011627
# 2022-04-26 16:52:41.470025:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10508-1650982250-heap.raw: 0.011695
# 2022-04-26 16:52:41.482157:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10511-1650982250-heap.raw: 0.012108
# 2022-04-26 16:52:41.494238:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10514-1650982250-heap.raw: 0.012058
# 2022-04-26 16:52:41.506535:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10517-1650982250-heap.raw: 0.012277
# 2022-04-26 16:52:41.518533:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10520-1650982250-heap.raw: 0.011979
# 2022-04-26 16:52:41.530488:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10523-1650982250-heap.raw: 0.011933
# 2022-04-26 16:52:41.542564:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10526-1650982250-heap.raw: 0.012058
# 2022-04-26 16:52:41.554187:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10529-1650982250-heap.raw: 0.011605
# 2022-04-26 16:52:41.565710:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10532-1650982250-heap.raw: 0.011507
# 2022-04-26 16:52:41.577800:	Total time taken for file /Users/stewartsentanoe/Documents/Uni Passau/projects/SmartVMI/Use Case 1 Data/Performance Test/V_7_1_P1/aes128-ctr/10535-1650982250-heap.raw: 0.012073

# %%
close() # Close the logging file pointers
